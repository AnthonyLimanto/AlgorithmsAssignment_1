# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t500hash = (1400 + 1300 + 1600 + 1600 + 1200) / 5 / 1000

t1000hash = (1700 + 1500
+
1200
+
1300
+
1500) / 5 / 1000
t5000hash = (2200 +
1800 +
1900 +
1400 +
1800 ) / 5 / 1000
t10000hash = (1700 +
1500 +
2000 + 
1600 +
1000) / 5 / 1000
t50000hash = (2000 + 1800 + 1400 + 1900 + 1800) / 5 / 1000
t100000hash = (1900 + 2800 + 1800 + 1600 + 2300) / 5 / 1000
t150000hash = (1600 + 3100 + 1600 + 2100 + 1600) / 5 / 1000
t200000hash = (2500 + 2200 + 2300 + 1900 + 2700) / 5 / 1000
print(f"{t500hash} {t1000hash} {t5000hash} {t10000hash} {t50000hash} {t100000hash} {t150000hash} {t200000hash}")

t500tst = (39000 + 60100 + 33700 + 42000 + 23200) / 5 / 1000

t1000tst = (40600 + 30300
+
51800
+
37400
+
37800) / 5 / 1000
t5000tst = (62100 +
47100 +
37100 +
73200 +
122100 ) / 5 / 1000
t10000tst = (68800 +
37700 +
39500 + 
50100 +
33000) / 5 / 1000
t50000tst = (53000 + 43400 + 61700 + 42400 + 40100) / 5 / 1000
t100000tst = (51600 + 40100 + 39200 + 22900 + 49000) / 5 / 1000
t150000tst = (74500 + 39700 + 43500 + 35400 + 74500) / 5 / 1000
t200000tst = (61200 + 24300 + 45700 + 51300 + 39500) / 5 / 1000
# Out:
# 1.42 1.44 1.82 1.56 1.78 2.08 2.0 2.32

# %%
x = np.array([500, 1000, 5000, 10000, 50000, 100000, 150000, 200000])
y = np.array([t500hash, t1000hash, t5000hash, t10000hash, t50000hash, t100000hash, t150000hash, t200000hash])

plt.plot(x, y, label = "hash")
plt.show()

# %%
# in microseconds
t500list = (47200 + 51000 + 53700 + 46900 + 46400) / 5 / 1000
t1000list = (92000 + 90000 + 102000 + 90000 + 97300) / 5 / 1000 
t5000list = (432500 + 433600 + 427300 + 458300 + 483400) / 5 / 1000
t10000list = (871500 + 868900 + 859800 + 942300 + 884200) / 5 / 1000
t50000list = (4812500 + 4439700 + 4444600 + 4460200 + 4381000) / 5 / 1000
t100000list = (8562000 + 8855400 + 8666600 + 8869000 + 8681800) / 5 / 1000
t150000list = (9751300 + 10651000 + 9948600 + 9871400 + 10034600) / 5 / 1000
t200000list = (17734300 + 18047800 + 17940500 + 25994200 + 17593700) / 5 / 1000
 
    
y2 = np.array([t500list, t1000list, t5000list, t10000list, t50000list, t100000list, t150000list, t200000list])
plt.plot(x, y2, label = "list")
plt.show()
y3 = np.array([t500tst, t1000tst, t5000tst, t10000tst, t50000tst, t100000tst, t150000tst, t200000tst])

# %%
plt.legend(['hash', 'list'])

# %%
plt.plot(x, y, label = "hash")
plt.plot(x, y3, label = "tst")
plt.plot(x, y2, label = "list")
plt.legend(['hash', 'tst', 'list'])
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.xlabel("Size of Dictionary")
plt.ylabel("Time in microseconds")
plt.show()

# %%
plt.plot(x, y, label = "hash")
plt.plot(x, y3, label = "tst")
plt.legend(['hash', 'tst'])
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.xlabel("Size of Dictionary")
plt.ylabel("Time in microseconds")
plt.show()

# %%
hashdelete500 = (1600 + 1400 + 2000 + 1200 + 2200 + 1500) / 6
hashdelete1000 = (2400 + 1300 + 1500 + 1200 + 1400 + 1300) / 6
hashdelete5000 = (2000 + 1400 + 2000 + 1300 + 2200 + 1700) / 6
hashdelete10000 = (2400 + 1700 + 1800 + 1400 + 1700 + 1600) / 6
hashdelete50000 = (2300 + 1900 + 2200 + 1700 + 2500 + 1700) / 6
hashdelete100000 = (3000 + 2100 + 3000 + 2000 + 2700 + 1900) / 6
hashdelete150000 = (2800 + 2400 + 2800 + 2600 + 2700 + 2200) / 6
hashdelete200000 = (3500 + 1900 + 2900 + 1800 + 2700 + 1500) / 6

listdelete500 = (41700 + 38700 + 42500 + 46600 + 41200 + 61500) / 6
listdelete1000 = (77700 + 75300 + 88300 + 78600 + 90600 + 87300) / 6
listdelete5000 = (526600 + 740100 + 376900 + 376900 + 427600 + 408500) / 6
listdelete10000 = (787900 + 919200 + 771000 + 1756500 + 780900 + 1178500) / 6
listdelete50000 = (4758000 + 6109300 + 4502000 + 4919300 + 4416700 + 5148600) / 6
listdelete100000 = (11563100 + 10947600 + 9307900 + 10192700 + 9319900 + 10114100) / 6
listdelete150000 = (14605400 + 15348500 + 14413900 + 15686900 + 14070500 + 15073300) / 6
listdelete200000 = (18696600 + 19974400 + 19755700 + 23667700 + 20688300 + 22197500) / 6

tstdelete500 = (32300 + 75500 + 99200 + 37900 + 94500 + 123200) / 6
tstdelete1000 = (18400 + 29600 + 19700 + 30100 + 35000 + 55000) / 6
tstdelete5000 = (24400 + 67600 + 15800 + 36000 + 19900 + 41800) / 6
tstdelete10000 = (42800 + 60300 + 22200 + 31100 + 23000 + 32200) / 6
tstdelete50000 = (29500 + 71200 + 37400 + 56700 + 29200 + 42600) / 6
tstdelete100000 = (50900 + 75800 + 40900 + 60700 + 43700 + 56700) / 6
tstdelete150000 = (31000 + 58500 + 20900 + 44100 + 19400 + 41300) / 6
tstdelete200000 = (40400 + 41800 + 19300 + 34300 + 14100 + 29200) / 6

del_y_hash = np.array([hashdelete200000, hashdelete150000, hashdelete100000, hashdelete50000, hashdelete10000, hashdelete5000, hashdelete1000, hashdelete500])
del_y_list = np.array([listdelete200000, listdelete150000, listdelete100000, listdelete50000, listdelete10000, listdelete5000, listdelete1000, listdelete500])
del_y_tst = np.array([tstdelete200000, tstdelete150000, tstdelete100000, tstdelete50000, tstdelete10000, tstdelete5000, tstdelete1000, tstdelete500])

x2 = np.array([200000, 150000, 100000, 50000, 10000, 5000, 1000, 500])

# %%
plt.plot(x2, del_y_hash, label = "hash")
plt.plot(x2, del_y_tst, label = "tst")
plt.legend(['hash', 'tst'])
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.xlabel("Size of Dictionary")
plt.ylabel("Time in microseconds")
plt.show()

# %%
plt.plot(x2, del_y_hash, label = "hash")
plt.plot(x2, del_y_tst, label = "tst")
plt.plot(x2, del_y_list, label = "list")
plt.legend(['hash', 'tst', 'list'])
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.xlabel("Size of Dictionary")
plt.ylabel("Time in microseconds")
plt.show()
